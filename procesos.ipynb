# %%
import psutil
import datetime

# %%
### *** CPU FUNCTIONS ***

# Number of logical CPUs in the system
print ("psutil.cpu_count() = {0}".format(psutil.cpu_count()))


### *** DISK FUNCTIONS ***

# List of named tuples containing all mounted disk partitions
dparts = psutil.disk_partitions()
print("psutil.disk_partitions() = {0}".format(dparts))

# Disk usage statistics
du = psutil.disk_usage('/')
print("psutil.disk_usage('/') = {0}".format(du))


### *** MEMORY FUNCTIONS ***

# System memory usage statistics
mem = psutil.virtual_memory()
print("psutil.virtual_memory() = {0}".format(mem))

THRESHOLD = 100 * 1024 * 1024  # 100MB
if mem.available <= THRESHOLD:
    print("warning, available memory below threshold")


### *** PROCESS FUNCTIONS ***

# List of current running process IDs.
pids = psutil.pids()
print("psutil.pids() = {0}".format(pids))


# Check whether the given PID exists in the current process list.
for proc in psutil.process_iter():
    try:
        pinfo = proc.as_dict(attrs=['pid', 'name'])
    except psutil.NoSuchProcess:
        pass
    else:
        print(pinfo)


### *** SYSTEM INFORMATION FUNCTIONS ***

# System boot time expressed in seconds since the epoch
boot_time = psutil.boot_time()
print("psutil.boot_time() = {0}".format(boot_time))

# System boot time converted to human readable format
print(datetime.datetime.fromtimestamp(psutil.boot_time()).strftime("%Y-%m-%d %H:%M:%S"))

# Users currently connected on the system
users = psutil.users()
print("psutil.users() = {0}".format(users))
# Out:
# psutil.cpu_count() = 4
# psutil.disk_partitions() = [sdiskpart(device='C:\\', mountpoint='C:\\', fstype='NTFS', opts='rw,fixed'), sdiskpart(device='D:\\', mountpoint='D:\\', fstype='NTFS', opts='rw,fixed')]
# psutil.disk_usage('/') = sdiskusage(total=164631670784, used=150650777600, free=13980893184, percent=91.5)
# psutil.virtual_memory() = svmem(total=8474497024, available=1161928704, percent=86.3, used=7312568320, free=1161928704)
# psutil.pids() = [0, 4, 56, 108, 536, 672, 752, 840, 848, 912, 984, 1004, 1012, 1056, 1064, 1096, 1188, 1248, 1332, 1344, 1356, 1388, 1428, 1440, 1448, 1460, 1468, 1504, 1520, 1524, 1536, 1564, 1568, 1584, 1604, 1672, 1776, 1808, 1856, 1864, 1884, 1888, 1920, 1972, 2004, 2040, 2152, 2204, 2292, 2348, 2356, 2372, 2444, 2516, 2524, 2648, 2660, 2740, 2792, 2824, 2832, 2840, 2848, 2912, 2920, 2928, 2952, 2960, 2968, 3012, 3108, 3120, 3140, 3208, 3216, 3336, 3360, 3432, 3444, 3488, 3496, 3536, 3812, 3840, 3940, 3948, 3976, 4000, 4012, 4016, 4044, 4092, 4144, 4204, 4280, 4292, 4312, 4348, 4364, 4384, 4520, 4592, 4676, 4724, 4804, 4948, 4956, 4988, 5040, 5052, 5068, 5140, 5192, 5212, 5224, 5256, 5268, 5316, 5488, 5492, 5496, 5504, 5520, 5576, 5592, 5604, 5620, 5632, 5704, 5712, 5716, 5736, 5744, 5768, 5840, 5848, 5856, 5864, 5872, 5888, 5896, 5912, 5932, 5940, 5948, 6000, 6012, 6024, 6052, 6068, 6076, 6136, 6160, 6176, 6184, 6192, 6200, 6208, 6216, 6244, 6260, 6268, 6296, 6340, 6364, 6416, 6492, 6528, 6560, 6720, 6764, 6824, 6952, 6960, 7028, 7100, 7120, 7204, 7208, 7240, 7272, 7344, 7612, 7696, 7848, 7944, 8040, 8056, 8096, 8156, 8240, 8312, 8392, 8424, 8568, 9104, 9272, 9284, 9292, 9296, 9608, 9756, 9804, 9832, 10084, 10308, 10384, 10392, 10452, 10460, 10580, 10624, 10656, 10688, 10756, 10864, 10908, 10944, 10952, 10964, 10992, 11044, 11068, 11076, 11132, 11236, 11492, 11668, 11700, 11772, 11856, 11876, 11936, 12048, 12116, 12160, 12252, 12308, 12384, 12592, 12632, 12728, 12828, 13096, 13104, 13224, 13280, 13376, 13452, 13616, 13648, 13724, 13756, 13800, 13836, 13864, 13896, 13948, 14104, 14116, 14124, 14128, 14180, 14204, 14312, 14356, 14492, 14504, 14528, 14600, 14676, 14700, 14708, 14952, 15000, 15004, 15060, 15072, 15180, 15196, 15392, 15396, 15436, 15488, 15500, 15576, 15588, 15660, 15716, 15788, 15908, 15932, 16064, 16244, 16348, 16368, 16392, 16420, 16516, 16600, 16612, 16656, 16680, 16688, 16696, 16820, 16836, 16884, 16932, 17000, 17120, 17224, 17316, 17352, 17396, 17444, 17552, 17616, 17828, 17920, 17956, 17988, 18016, 18504, 18520, 18532, 18696, 18776, 18816, 18836, 18868, 18928, 18960, 18972, 19008, 19044, 19080, 19088, 19092, 19132, 19140, 19156, 19208, 19260, 19320, 19356, 19576, 19580, 19704, 19720, 19736, 19748, 19776, 19832, 20136, 20160, 20464, 20568, 20596, 20740, 20784, 21008, 21512, 21604, 21632, 21664, 21744, 21760, 21792, 22112, 22304, 22356, 22536, 22544, 22564, 22680, 22960, 22980, 23328, 23468, 23476, 23692, 23968, 24008, 24292, 24344, 24388, 24656, 24812, 25124, 25364]
# {'pid': 0, 'name': 'System Idle Process'}
# {'pid': 4, 'name': 'System'}
# {'pid': 56, 'name': ''}
# {'pid': 108, 'name': 'Registry'}
# {'pid': 536, 'name': 'smss.exe'}
# {'pid': 672, 'name': 'svchost.exe'}
# {'pid': 752, 'name': 'csrss.exe'}
# {'pid': 840, 'name': 'wininit.exe'}
# {'pid': 848, 'name': 'csrss.exe'}
# {'pid': 912, 'name': 'winlogon.exe'}
# {'pid': 984, 'name': 'services.exe'}
# {'pid': 1004, 'name': 'LsaIso.exe'}
# {'pid': 1012, 'name': 'lsass.exe'}
# {'pid': 1056, 'name': 'fontdrvhost.exe'}
# {'pid': 1064, 'name': 'fontdrvhost.exe'}
# {'pid': 1096, 'name': 'WUDFHost.exe'}
# {'pid': 1188, 'name': 'svchost.exe'}
# {'pid': 1248, 'name': 'svchost.exe'}
# {'pid': 1332, 'name': 'dwm.exe'}
# {'pid': 1344, 'name': 'chrome.exe'}
# {'pid': 1356, 'name': 'AdobeCollabSync.exe'}
# {'pid': 1388, 'name': 'chrome.exe'}
# {'pid': 1428, 'name': 'chrome.exe'}
# {'pid': 1440, 'name': 'svchost.exe'}
# {'pid': 1448, 'name': 'chrome.exe'}
# {'pid': 1460, 'name': 'svchost.exe'}
# {'pid': 1468, 'name': 'svchost.exe'}
# {'pid': 1504, 'name': 'YourPhone.exe'}
# {'pid': 1520, 'name': 'bdagent.exe'}
# {'pid': 1524, 'name': 'svchost.exe'}
# {'pid': 1536, 'name': 'svchost.exe'}
# {'pid': 1564, 'name': 'jhi_service.exe'}
# {'pid': 1568, 'name': 'chrome.exe'}
# {'pid': 1584, 'name': 'svchost.exe'}
# {'pid': 1604, 'name': 'svchost.exe'}
# {'pid': 1672, 'name': 'svchost.exe'}
# {'pid': 1776, 'name': 'svchost.exe'}
# {'pid': 1808, 'name': 'svchost.exe'}
# {'pid': 1856, 'name': 'svchost.exe'}
# {'pid': 1864, 'name': 'svchost.exe'}
# {'pid': 1884, 'name': 'chrome.exe'}
# {'pid': 1888, 'name': 'svchost.exe'}
# {'pid': 1920, 'name': 'svchost.exe'}
# {'pid': 1972, 'name': 'svchost.exe'}
# {'pid': 2004, 'name': 'svchost.exe'}
# {'pid': 2040, 'name': 'svchost.exe'}
# {'pid': 2152, 'name': 'svchost.exe'}
# {'pid': 2204, 'name': 'svchost.exe'}
# {'pid': 2292, 'name': 'svchost.exe'}
# {'pid': 2348, 'name': 'explorer.exe'}
# {'pid': 2356, 'name': 'svchost.exe'}
# {'pid': 2372, 'name': 'python.exe'}
# {'pid': 2444, 'name': 'svchost.exe'}
# {'pid': 2516, 'name': 'svchost.exe'}
# {'pid': 2524, 'name': 'svchost.exe'}
# {'pid': 2648, 'name': 'svchost.exe'}
# {'pid': 2660, 'name': 'dasHost.exe'}
# {'pid': 2740, 'name': 'svchost.exe'}
# {'pid': 2792, 'name': 'vmms.exe'}
# {'pid': 2824, 'name': 'svchost.exe'}
# {'pid': 2832, 'name': 'svchost.exe'}
# {'pid': 2840, 'name': 'chrome.exe'}
# {'pid': 2848, 'name': 'chrome.exe'}
# {'pid': 2912, 'name': 'svchost.exe'}
# {'pid': 2920, 'name': 'svchost.exe'}
# {'pid': 2928, 'name': 'svchost.exe'}
# {'pid': 2952, 'name': 'svchost.exe'}
# {'pid': 2960, 'name': 'svchost.exe'}
# {'pid': 2968, 'name': 'mintty.exe'}
# {'pid': 3012, 'name': 'svchost.exe'}
# {'pid': 3108, 'name': 'MemCompression'}
# {'pid': 3120, 'name': 'igfxCUIService.exe'}
# {'pid': 3140, 'name': 'SystemSettings.exe'}
# {'pid': 3208, 'name': 'svchost.exe'}
# {'pid': 3216, 'name': 'svchost.exe'}
# {'pid': 3336, 'name': 'svchost.exe'}
# {'pid': 3360, 'name': 'svchost.exe'}
# {'pid': 3432, 'name': 'svchost.exe'}
# {'pid': 3444, 'name': 'SynTPEnh.exe'}
# {'pid': 3488, 'name': 'wlanext.exe'}
# {'pid': 3496, 'name': 'svchost.exe'}
# {'pid': 3536, 'name': 'Postman.exe'}
# {'pid': 3812, 'name': 'svchost.exe'}
# {'pid': 3840, 'name': 'UserOOBEBroker.exe'}
# {'pid': 3940, 'name': 'dasHost.exe'}
# {'pid': 3948, 'name': 'svchost.exe'}
# {'pid': 3976, 'name': 'FortiClient.exe'}
# {'pid': 4000, 'name': 'svchost.exe'}
# {'pid': 4012, 'name': 'smartscreen.exe'}
# {'pid': 4016, 'name': 'svchost.exe'}
# {'pid': 4044, 'name': 'svchost.exe'}
# {'pid': 4092, 'name': 'svchost.exe'}
# {'pid': 4144, 'name': 'svchost.exe'}
# {'pid': 4204, 'name': 'svchost.exe'}
# {'pid': 4280, 'name': 'ParameterService.exe'}
# {'pid': 4292, 'name': 'RtkAudioService64.exe'}
# {'pid': 4312, 'name': 'chrome.exe'}
# {'pid': 4348, 'name': 'svchost.exe'}
# {'pid': 4364, 'name': 'svchost.exe'}
# {'pid': 4384, 'name': 'igfxEM.exe'}
# {'pid': 4520, 'name': 'svchost.exe'}
# {'pid': 4592, 'name': 'svchost.exe'}
# {'pid': 4676, 'name': 'RAVBg64.exe'}
# {'pid': 4724, 'name': 'Adobe CEF Helper.exe'}
# {'pid': 4804, 'name': 'scheduler.exe'}
# {'pid': 4948, 'name': 'svchost.exe'}
# {'pid': 4956, 'name': 'svchost.exe'}
# {'pid': 4988, 'name': 'conhost.exe'}
# {'pid': 5040, 'name': 'vmwp.exe'}
# {'pid': 5052, 'name': 'svchost.exe'}
# {'pid': 5068, 'name': 'svchost.exe'}
# {'pid': 5140, 'name': 'svchost.exe'}
# {'pid': 5192, 'name': 'RuntimeBroker.exe'}
# {'pid': 5212, 'name': 'chrome.exe'}
# {'pid': 5224, 'name': 'chrome.exe'}
# {'pid': 5256, 'name': 'escsvc64.exe'}
# {'pid': 5268, 'name': 'EPCP.exe'}
# {'pid': 5316, 'name': 'FCDBLog.exe'}
# {'pid': 5488, 'name': 'openvpnserv.exe'}
# {'pid': 5492, 'name': 'chrome.exe'}
# {'pid': 5496, 'name': 'FortiSSLVPNdaemon.exe'}
# {'pid': 5504, 'name': 'FortiSettings.exe'}
# {'pid': 5520, 'name': 'svchost.exe'}
# {'pid': 5576, 'name': 'chrome.exe'}
# {'pid': 5592, 'name': 'svchost.exe'}
# {'pid': 5604, 'name': 'UpdaterService.exe'}
# {'pid': 5620, 'name': 'mqsvc.exe'}
# {'pid': 5632, 'name': 'IPROSetMonitor.exe'}
# {'pid': 5704, 'name': 'bash.exe'}
# {'pid': 5712, 'name': 'SMSvcHost.exe'}
# {'pid': 5716, 'name': 'ProductAgentService.exe'}
# {'pid': 5736, 'name': 'ApplicationFrameHost.exe'}
# {'pid': 5744, 'name': 'SbaService.exe'}
# {'pid': 5768, 'name': 'spoolsv.exe'}
# {'pid': 5840, 'name': 'AppleMobileDeviceService.exe'}
# {'pid': 5848, 'name': 'armsvc.exe'}
# {'pid': 5856, 'name': 'bdredline.exe'}
# {'pid': 5864, 'name': 'AdobeUpdateService.exe'}
# {'pid': 5872, 'name': 'svchost.exe'}
# {'pid': 5888, 'name': 'remoting_host.exe'}
# {'pid': 5896, 'name': 'AGSService.exe'}
# {'pid': 5912, 'name': 'svchost.exe'}
# {'pid': 5932, 'name': 'svchost.exe'}
# {'pid': 5940, 'name': 'AdminService.exe'}
# {'pid': 5948, 'name': 'AGMService.exe'}
# {'pid': 6000, 'name': 'DockingService.exe'}
# {'pid': 6012, 'name': 'Skype.exe'}
# {'pid': 6024, 'name': 'DashlaneUpgradeService.exe'}
# {'pid': 6052, 'name': 'svchost.exe'}
# {'pid': 6068, 'name': 'ElevationService.exe'}
# {'pid': 6076, 'name': 'svchost.exe'}
# {'pid': 6136, 'name': 'ePowerSvc.exe'}
# {'pid': 6160, 'name': 'svchost.exe'}
# {'pid': 6176, 'name': 'svchost.exe'}
# {'pid': 6184, 'name': 'httpd.exe'}
# {'pid': 6192, 'name': 'SynTPEnhService.exe'}
# {'pid': 6200, 'name': 'svchost.exe'}
# {'pid': 6208, 'name': 'mysqld.exe'}
# {'pid': 6216, 'name': 'Skype.exe'}
# {'pid': 6244, 'name': 'updatesrv.exe'}
# {'pid': 6260, 'name': 'vsserv.exe'}
# {'pid': 6268, 'name': 'Skype.exe'}
# {'pid': 6296, 'name': 'vsservppl.exe'}
# {'pid': 6340, 'name': 'WebManagement.exe'}
# {'pid': 6364, 'name': 'Skype.exe'}
# {'pid': 6416, 'name': 'svchost.exe'}
# {'pid': 6492, 'name': 'InstallAssistService.exe'}
# {'pid': 6528, 'name': 'vmcompute.exe'}
# {'pid': 6560, 'name': 'chrome.exe'}
# {'pid': 6720, 'name': 'svchost.exe'}
# {'pid': 6764, 'name': 'chrome.exe'}
# {'pid': 6824, 'name': 'SgrmBroker.exe'}
# {'pid': 6952, 'name': 'mysqld.exe'}
# {'pid': 6960, 'name': 'svchost.exe'}
# {'pid': 7028, 'name': 'conhost.exe'}
# {'pid': 7100, 'name': 'svchost.exe'}
# {'pid': 7120, 'name': 'remoting_host.exe'}
# {'pid': 7204, 'name': 'SMSvcHost.exe'}
# {'pid': 7208, 'name': 'svchost.exe'}
# {'pid': 7240, 'name': 'com.docker.service'}
# {'pid': 7272, 'name': 'AdobeNotificationClient.exe'}
# {'pid': 7344, 'name': 'vmmem'}
# {'pid': 7612, 'name': 'svchost.exe'}
# {'pid': 7696, 'name': 'FortiClient.exe'}
# {'pid': 7848, 'name': 'unsecapp.exe'}
# {'pid': 7944, 'name': 'WmiPrvSE.exe'}
# {'pid': 8040, 'name': 'SecurityHealthService.exe'}
# {'pid': 8056, 'name': 'WmiPrvSE.exe'}
# {'pid': 8096, 'name': 'svchost.exe'}
# {'pid': 8156, 'name': 'chrome.exe'}
# {'pid': 8240, 'name': 'httpd.exe'}
# {'pid': 8312, 'name': 'svchost.exe'}
# {'pid': 8392, 'name': 'Adobe CEF Helper.exe'}
# {'pid': 8424, 'name': 'svchost.exe'}
# {'pid': 8568, 'name': 'LMS.exe'}
# {'pid': 9104, 'name': 'conhost.exe'}
# {'pid': 9272, 'name': 'SecurityHealthSystray.exe'}
# {'pid': 9284, 'name': 'dllhost.exe'}
# {'pid': 9292, 'name': 'wslhost.exe'}
# {'pid': 9296, 'name': 'svchost.exe'}
# {'pid': 9608, 'name': 'chrome.exe'}
# {'pid': 9756, 'name': 'dllhost.exe'}
# {'pid': 9804, 'name': 'svchost.exe'}
# {'pid': 9832, 'name': 'svchost.exe'}
# {'pid': 10084, 'name': 'SearchFilterHost.exe'}
# {'pid': 10308, 'name': 'svchost.exe'}
# {'pid': 10384, 'name': 'dllhost.exe'}
# {'pid': 10392, 'name': 'DiscoverySrv.exe'}
# {'pid': 10452, 'name': 'SynTPHelper.exe'}
# {'pid': 10460, 'name': 'svchost.exe'}
# {'pid': 10580, 'name': 'sihost.exe'}
# {'pid': 10624, 'name': 'FortiTray.exe'}
# {'pid': 10656, 'name': 'svchost.exe'}
# {'pid': 10688, 'name': 'chrome.exe'}
# {'pid': 10756, 'name': 'svchost.exe'}
# {'pid': 10864, 'name': 'RuntimeBroker.exe'}
# {'pid': 10908, 'name': 'PresentationFontCache.exe'}
# {'pid': 10944, 'name': 'taskhostw.exe'}
# {'pid': 10952, 'name': 'chrome.exe'}
# {'pid': 10964, 'name': 'svchost.exe'}
# {'pid': 10992, 'name': 'svchost.exe'}
# {'pid': 11044, 'name': 'chrome.exe'}
# {'pid': 11068, 'name': 'svchost.exe'}
# {'pid': 11076, 'name': 'svchost.exe'}
# {'pid': 11132, 'name': 'ctfmon.exe'}
# {'pid': 11236, 'name': 'chrome.exe'}
# {'pid': 11492, 'name': 'svchost.exe'}
# {'pid': 11668, 'name': 'svchost.exe'}
# {'pid': 11700, 'name': 'AcrobatNotificationClient.exe'}
# {'pid': 11772, 'name': 'FortiClient.exe'}
# {'pid': 11856, 'name': 'StartMenuExperienceHost.exe'}
# {'pid': 11876, 'name': 'WinStore.App.exe'}
# {'pid': 11936, 'name': 'RuntimeBroker.exe'}
# {'pid': 12048, 'name': 'SearchApp.exe'}
# {'pid': 12116, 'name': 'RuntimeBroker.exe'}
# {'pid': 12160, 'name': 'RuntimeBroker.exe'}
# {'pid': 12252, 'name': 'BtvStack.exe'}
# {'pid': 12308, 'name': 'python.exe'}
# {'pid': 12384, 'name': 'Postman.exe'}
# {'pid': 12592, 'name': 'SettingSyncHost.exe'}
# {'pid': 12632, 'name': 'TextInputHost.exe'}
# {'pid': 12728, 'name': 'RuntimeBroker.exe'}
# {'pid': 12828, 'name': 'wslhost.exe'}
# {'pid': 13096, 'name': 'GoogleCrashHandler.exe'}
# {'pid': 13104, 'name': 'GoogleCrashHandler64.exe'}
# {'pid': 13224, 'name': 'conhost.exe'}
# {'pid': 13280, 'name': 'jupyter-notebook.exe'}
# {'pid': 13376, 'name': 'RAVCpl64.exe'}
# {'pid': 13452, 'name': 'FFP_Token.exe'}
# {'pid': 13616, 'name': 'BtTray.exe'}
# {'pid': 13648, 'name': 'AcrobatNotificationClient.exe'}
# {'pid': 13724, 'name': 'ePowerTray.exe'}
# {'pid': 13756, 'name': 'igfxext.exe'}
# {'pid': 13800, 'name': 'unsecapp.exe'}
# {'pid': 13836, 'name': 'ePowerEvent.exe'}
# {'pid': 13864, 'name': 'chrome.exe'}
# {'pid': 13896, 'name': 'unsecapp.exe'}
# {'pid': 13948, 'name': 'Docker Desktop.exe'}
# {'pid': 14104, 'name': 'openvpn-gui.exe'}
# {'pid': 14116, 'name': 'Postman.exe'}
# {'pid': 14124, 'name': 'conhost.exe'}
# {'pid': 14128, 'name': 'com.docker.backend.exe'}
# {'pid': 14180, 'name': 'AdobeCollabSync.exe'}
# {'pid': 14204, 'name': 'AdobeCollabSync.exe'}
# {'pid': 14312, 'name': 'AdobeCollabSync.exe'}
# {'pid': 14356, 'name': 'Postman.exe'}
# {'pid': 14492, 'name': 'dllhost.exe'}
# {'pid': 14504, 'name': 'chrome.exe'}
# {'pid': 14528, 'name': 'jusched.exe'}
# {'pid': 14600, 'name': 'chrome.exe'}
# {'pid': 14676, 'name': 'chrome.exe'}
# {'pid': 14700, 'name': 'chrome.exe'}
# {'pid': 14708, 'name': 'chrome.exe'}
# {'pid': 14952, 'name': 'chrome.exe'}
# {'pid': 15000, 'name': 'conhost.exe'}
# {'pid': 15004, 'name': 'chrome.exe'}
# {'pid': 15060, 'name': 'chrome.exe'}
# {'pid': 15072, 'name': 'chrome.exe'}
# {'pid': 15180, 'name': 'svchost.exe'}
# {'pid': 15196, 'name': 'chrome.exe'}
# {'pid': 15392, 'name': 'chrome.exe'}
# {'pid': 15396, 'name': 'chrome.exe'}
# {'pid': 15436, 'name': 'cmd.exe'}
# {'pid': 15488, 'name': 'Postman.exe'}
# {'pid': 15500, 'name': 'chrome.exe'}
# {'pid': 15576, 'name': 'chrome.exe'}
# {'pid': 15588, 'name': 'chrome.exe'}
# {'pid': 15660, 'name': 'AppVShNotify.exe'}
# {'pid': 15716, 'name': 'RuntimeBroker.exe'}
# {'pid': 15788, 'name': 'Skype.exe'}
# {'pid': 15908, 'name': 'conhost.exe'}
# {'pid': 15932, 'name': 'wslhost.exe'}
# {'pid': 16064, 'name': 'ShellExperienceHost.exe'}
# {'pid': 16244, 'name': 'Skype.exe'}
# {'pid': 16348, 'name': 'sqldeveloper64W.exe'}
# {'pid': 16368, 'name': 'svchost.exe'}
# {'pid': 16392, 'name': 'Creative Cloud.exe'}
# {'pid': 16420, 'name': 'Creative Cloud Helper.exe'}
# {'pid': 16516, 'name': 'RuntimeBroker.exe'}
# {'pid': 16600, 'name': 'PrivacyIconClient.exe'}
# {'pid': 16612, 'name': 'CCXProcess.exe'}
# {'pid': 16656, 'name': 'node.exe'}
# {'pid': 16680, 'name': 'svchost.exe'}
# {'pid': 16688, 'name': 'conhost.exe'}
# {'pid': 16696, 'name': 'acrotray.exe'}
# {'pid': 16820, 'name': 'EEventManager.exe'}
# {'pid': 16836, 'name': 'chrome.exe'}
# {'pid': 16884, 'name': 'AdobeIPCBroker.exe'}
# {'pid': 16932, 'name': 'RuntimeBroker.exe'}
# {'pid': 17000, 'name': 'FUFAXRCV.exe'}
# {'pid': 17120, 'name': 'jucheck.exe'}
# {'pid': 17224, 'name': 'Creative Cloud Helper.exe'}
# {'pid': 17316, 'name': 'Adobe CEF Helper.exe'}
# {'pid': 17352, 'name': 'Adobe Desktop Service.exe'}
# {'pid': 17396, 'name': 'svchost.exe'}
# {'pid': 17444, 'name': 'CoreSync.exe'}
# {'pid': 17552, 'name': 'Calculator.exe'}
# {'pid': 17616, 'name': 'chrome.exe'}
# {'pid': 17828, 'name': 'conhost.exe'}
# {'pid': 17920, 'name': 'CCLibrary.exe'}
# {'pid': 17956, 'name': 'node.exe'}
# {'pid': 17988, 'name': 'conhost.exe'}
# {'pid': 18016, 'name': 'RuntimeBroker.exe'}
# {'pid': 18504, 'name': 'python.exe'}
# {'pid': 18520, 'name': 'chrome.exe'}
# {'pid': 18532, 'name': 'wsl.exe'}
# {'pid': 18696, 'name': 'wslhost.exe'}
# {'pid': 18776, 'name': 'wsl.exe'}
# {'pid': 18816, 'name': 'conhost.exe'}
# {'pid': 18836, 'name': 'git-bash.exe'}
# {'pid': 18868, 'name': 'Screenpresso.exe'}
# {'pid': 18928, 'name': 'wsl.exe'}
# {'pid': 18960, 'name': 'vpnkit-bridge.exe'}
# {'pid': 18972, 'name': 'conhost.exe'}
# {'pid': 19008, 'name': 'conhost.exe'}
# {'pid': 19044, 'name': 'vpnkit.exe'}
# {'pid': 19080, 'name': 'conhost.exe'}
# {'pid': 19088, 'name': 'chrome.exe'}
# {'pid': 19092, 'name': 'docker.exe'}
# {'pid': 19132, 'name': 'com.docker.proxy.exe'}
# {'pid': 19140, 'name': 'R.exe'}
# {'pid': 19156, 'name': 'conhost.exe'}
# {'pid': 19208, 'name': 'conhost.exe'}
# {'pid': 19260, 'name': 'Adobe Installer.exe'}
# {'pid': 19320, 'name': 'svchost.exe'}
# {'pid': 19356, 'name': 'conhost.exe'}
# {'pid': 19576, 'name': 'chrome.exe'}
# {'pid': 19580, 'name': 'chrome.exe'}
# {'pid': 19704, 'name': 'R.exe'}
# {'pid': 19720, 'name': 'cmd.exe'}
# {'pid': 19736, 'name': 'LockApp.exe'}
# {'pid': 19748, 'name': 'Rterm.exe'}
# {'pid': 19776, 'name': 'chrome.exe'}
# {'pid': 19832, 'name': 'chrome.exe'}
# {'pid': 20136, 'name': 'chrome.exe'}
# {'pid': 20160, 'name': 'chrome.exe'}
# {'pid': 20464, 'name': 'conhost.exe'}
# {'pid': 20568, 'name': 'OfficeClickToRun.exe'}
# {'pid': 20596, 'name': 'chrome.exe'}
# {'pid': 20740, 'name': 'chrome.exe'}
# {'pid': 20784, 'name': 'SearchProtocolHost.exe'}
# {'pid': 21008, 'name': 'chrome.exe'}
# {'pid': 21512, 'name': 'svchost.exe'}
# {'pid': 21604, 'name': 'chrome.exe'}
# {'pid': 21632, 'name': 'chrome.exe'}
# {'pid': 21664, 'name': 'audiodg.exe'}
# {'pid': 21744, 'name': 'pythonw.exe'}
# {'pid': 21760, 'name': 'chrome.exe'}
# {'pid': 21792, 'name': 'chrome.exe'}
# {'pid': 22112, 'name': 'chrome.exe'}
# {'pid': 22304, 'name': 'svchost.exe'}
# {'pid': 22356, 'name': 'chrome.exe'}
# {'pid': 22536, 'name': 'SearchIndexer.exe'}
# {'pid': 22544, 'name': 'chrome.exe'}
# {'pid': 22564, 'name': 'chrome.exe'}
# {'pid': 22680, 'name': 'chrome.exe'}
# {'pid': 22960, 'name': 'cmd.exe'}
# {'pid': 22980, 'name': 'chrome.exe'}
# {'pid': 23328, 'name': 'Postman.exe'}
# {'pid': 23468, 'name': 'Postman.exe'}
# {'pid': 23476, 'name': 'pythonw.exe'}
# {'pid': 23692, 'name': 'chrome.exe'}
# {'pid': 23968, 'name': 'chrome.exe'}
# {'pid': 24008, 'name': 'chrome.exe'}
# {'pid': 24292, 'name': 'chrome.exe'}
# {'pid': 24344, 'name': 'AppVShNotify.exe'}
# {'pid': 24388, 'name': 'chrome.exe'}
# {'pid': 24656, 'name': 'svchost.exe'}
# {'pid': 24812, 'name': 'chrome.exe'}
# {'pid': 25124, 'name': 'chrome.exe'}
# {'pid': 25364, 'name': 'rundll32.exe'}
# psutil.boot_time() = 1619471859.2816956
# 2021-04-26 18:17:39
# psutil.users() = [suser(name='pablo', terminal=None, host=None, started=1619471861.6582425, pid=None)]
